# %%
import dtale
import os
import pandas as pd
import dtale.app as dtale_app
from IPython.display import display
from IPython.display import IFrame

dtale_app.JUPYTER_SERVER_PROXY = True

app_root = '{}proxy/'.format(os.environ['JUPYTERHUB_SERVICE_PREFIX'])
port = 40000

df = pd.DataFrame([1,2,3,4,5])
d = dtale.show(
    df,
    port=port,
    app_root=app_root
)

iframe_url = 'https://hub.gke2.mybinder.org{}{}/dtale/main/{}'.format(
    app_root,
    port,
    d._data_id,
)


display(IFrame(iframe_url, width='100%', height=475))
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/dash_bootstrap_components/_table.py:5: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#         <iframe
#             width="100%"
#             height="475"
#             src="https://hub.gke2.mybinder.org/user/aschonfeld-dtale-binder-bxn9sxjl/proxy/40000/dtale/main/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
